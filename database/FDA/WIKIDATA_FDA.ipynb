# %%
import csv
import pandas as pd

# %%
df_indi = pd.read_csv('./ASCII/INDI20Q1.txt', delimiter = "$")
df_indi.head()
# Out:
#    primaryid    caseid  indi_drug_seq                            indi_pt
# 0  100046942  10004694              1  Low density lipoprotein increased
# 1  100046942  10004694              2   Cardiovascular event prophylaxis
# 2  100048206  10004820              1                           Epilepsy
# 3  100048206  10004820              2                   Partial seizures
# 4  100048622  10004862              1  Low density lipoprotein increased

# %%
df_drug = pd.read_csv('./ASCII/DRUG20Q1.txt', delimiter = "$")
df_drug.head()
# Out:
#    primaryid    caseid  drug_seq role_cod               drugname  \
# 0  100046942  10004694         1       PS                LIPITOR
# 1  100046942  10004694         2       SS                LIPITOR
# 2  100046942  10004694         3       SS  ATORVASTATIN CALCIUM.
# 3  100046942  10004694         4        C                  ZOCOR
# 4  100046942  10004694         5        C           SIMVASTATIN.
#
#                 prod_ai  val_vbm route          dose_vbm  cum_dose_chr  \
# 0  ATORVASTATIN CALCIUM        1  Oral      20 MG, DAILY           NaN
# 1  ATORVASTATIN CALCIUM        1   NaN               NaN           NaN
# 2  ATORVASTATIN CALCIUM        1  Oral      20 MG, DAILY           NaN
# 3           SIMVASTATIN        1   NaN  (40-80 MG) DAILY           NaN
# 4           SIMVASTATIN        1   NaN      40 MG, DAILY           NaN
#
#   cum_dose_unit dechal rechal lot_num exp_dt  nda_num  dose_amt dose_unit  \
# ...

# %%
df_res = df_indi.merge(df_drug, on='primaryid')[['primaryid', 'drugname', 'indi_pt']]
df_res.head()
# Out:
#    primaryid               drugname                            indi_pt
# 0  100046942                LIPITOR  Low density lipoprotein increased
# 1  100046942                LIPITOR  Low density lipoprotein increased
# 2  100046942  ATORVASTATIN CALCIUM.  Low density lipoprotein increased
# 3  100046942                  ZOCOR  Low density lipoprotein increased
# 4  100046942           SIMVASTATIN.  Low density lipoprotein increased

# %%
df_res.to_csv(r'wiki_fda_data.txt', index=None, sep='\t')
